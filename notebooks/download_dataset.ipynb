# %%
import numpy as numpy

# %%
import json
with open('../artifacts/kaggle.json', 'r') as file:
    data = json.load(file)

# %%
data
# Out:
# {'username': 'aksddhananja', 'key': 'fcf86fe8d02364e03a8d58a0fb16ee77'}

# %%
# !pip install kaggle
# Out:
# Collecting kaggle
#   Downloading kaggle-2.2.1-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: bleach in D:\Python\sentiment-analysis-project\env\Lib\site-packages (from kaggle) (6.4.0)
# Collecting jupytext (from kaggle)
#   Downloading jupytext-1.19.3-py3-none-any.whl.metadata (15 kB)
# Collecting kagglesdk<1.0,>=0.1.27 (from kaggle)
#   Downloading kagglesdk-0.1.28-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: packaging in D:\Python\sentiment-analysis-project\env\Lib\site-packages (from kaggle) (26.2)
# Collecting protobuf (from kaggle)
#   Downloading protobuf-7.35.0-cp310-abi3-win_amd64.whl.metadata (595 bytes)
# Requirement already satisfied: python-dateutil in D:\Python\sentiment-analysis-project\env\Lib\site-packages (from kaggle) (2.9.0.post0)
# Collecting python-dotenv (from kaggle)
#   Downloading python_dotenv-1.2.2-py3-none-any.whl.metadata (27 kB)
# Collecting python-slugify (from kaggle)
#   Downloading python_slugify-8.0.4-py2.py3-none-any.whl.metadata (8.5 kB)
# Requirement already satisfied: requests in D:\Python\sentiment-analysis-project\env\Lib\site-packages (from kaggle) (2.34.2)
# Collecting tqdm (from kaggle)
#   Downloading tqdm-4.68.2-py3-none-any.whl.metadata (58 kB)
# Requirement already satisfied: urllib3>=1.15.1 in D:\Python\sentiment-analysis-project\env\Lib\site-packages (from kaggle) (2.7.0)
# Requirement already satisfied: webencodings in D:\Python\sentiment-analysis-project\env\Lib\site-packages (from bleach->kaggle) (0.5.1)
# Collecting markdown-it-py>=1.0 (from jupytext->kaggle)
#   Using cached markdown_it_py-4.2.0-py3-none-any.whl.metadata (7.4 kB)
# Collecting mdit-py-plugins (from jupytext->kaggle)
#   Downloading mdit_py_plugins-0.6.1-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: nbformat in D:\Python\sentiment-analysis-project\env\Lib\site-packages (from jupytext->kaggle) (5.10.4)
# Requirement already satisfied: pyyaml in D:\Python\sentiment-analysis-project\env\Lib\site-packages (from jupytext->kaggle) (6.0.3)
# Collecting mdurl~=0.1 (from markdown-it-py>=1.0->jupytext->kaggle)
#   Using cached mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: fastjsonschema>=2.15 in D:\Python\sentiment-analysis-project\env\Lib\site-packages (from nbformat->jupytext->kaggle) (2.21.2)
# Requirement already satisfied: jsonschema>=2.6 in D:\Python\sentiment-analysis-project\env\Lib\site-packages (from nbformat->jupytext->kaggle) (4.26.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in D:\Python\sentiment-analysis-project\env\Lib\site-packages (from nbformat->jupytext->kaggle) (5.9.1)
# Requirement already satisfied: traitlets>=5.1 in D:\Python\sentiment-analysis-project\env\Lib\site-packages (from nbformat->jupytext->kaggle) (5.15.1)
# Requirement already satisfied: attrs>=22.2.0 in D:\Python\sentiment-analysis-project\env\Lib\site-packages (from jsonschema>=2.6->nbformat->jupytext->kaggle) (26.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in D:\Python\sentiment-analysis-project\env\Lib\site-packages (from jsonschema>=2.6->nbformat->jupytext->kaggle) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in D:\Python\sentiment-analysis-project\env\Lib\site-packages (from jsonschema>=2.6->nbformat->jupytext->kaggle) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in D:\Python\sentiment-analysis-project\env\Lib\site-packages (from jsonschema>=2.6->nbformat->jupytext->kaggle) (2026.5.1)
# Requirement already satisfied: platformdirs>=2.5 in D:\Python\sentiment-analysis-project\env\Lib\site-packages (from jupyter-core!=5.0.*,>=4.12->nbformat->jupytext->kaggle) (4.10.0)
# Requirement already satisfied: six>=1.5 in D:\Python\sentiment-analysis-project\env\Lib\site-packages (from python-dateutil->kaggle) (1.17.0)
# Collecting text-unidecode>=1.3 (from python-slugify->kaggle)
#   Downloading text_unidecode-1.3-py2.py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in D:\Python\sentiment-analysis-project\env\Lib\site-packages (from requests->kaggle) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in D:\Python\sentiment-analysis-project\env\Lib\site-packages (from requests->kaggle) (3.18)
# Requirement already satisfied: certifi>=2023.5.7 in D:\Python\sentiment-analysis-project\env\Lib\site-packages (from requests->kaggle) (2026.5.20)
# Requirement already satisfied: colorama in D:\Python\sentiment-analysis-project\env\Lib\site-packages (from tqdm->kaggle) (0.4.6)
# Downloading kaggle-2.2.1-py3-none-any.whl (132 kB)
# Downloading kagglesdk-0.1.28-py3-none-any.whl (230 kB)
# Downloading jupytext-1.19.3-py3-none-any.whl (170 kB)
# Using cached markdown_it_py-4.2.0-py3-none-any.whl (91 kB)
# Using cached mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Downloading mdit_py_plugins-0.6.1-py3-none-any.whl (66 kB)
# Downloading protobuf-7.35.0-cp310-abi3-win_amd64.whl (439 kB)
# Downloading python_dotenv-1.2.2-py3-none-any.whl (22 kB)
# Downloading python_slugify-8.0.4-py2.py3-none-any.whl (10 kB)
# Downloading text_unidecode-1.3-py2.py3-none-any.whl (78 kB)
# Downloading tqdm-4.68.2-py3-none-any.whl (78 kB)
# Installing collected packages: text-unidecode, tqdm, python-slugify, python-dotenv, protobuf, mdurl, markdown-it-py, kagglesdk, mdit-py-plugins, jupytext, kaggle
#
#    --- ------------------------------------  1/11 [tqdm]
#    --- ------------------------------------  1/11 [tqdm]
#    --- ------------------------------------  1/11 [tqdm]
#    --- ------------------------------------  1/11 [tqdm]
#    --- ------------------------------------  1/11 [tqdm]
#    --- ------------------------------------  1/11 [tqdm]
#    --- ------------------------------------  1/11 [tqdm]
#    ------- --------------------------------  2/11 [python-slugify]
#    ------- --------------------------------  2/11 [python-slugify]
#    ---------- -----------------------------  3/11 [python-dotenv]
#    ---------- -----------------------------  3/11 [python-dotenv]
#    ---------- -----------------------------  3/11 [python-dotenv]
#    -------------- -------------------------  4/11 [protobuf]
#    -------------- -------------------------  4/11 [protobuf]
#    -------------- -------------------------  4/11 [protobuf]
#    -------------- -------------------------  4/11 [protobuf]
#    -------------- -------------------------  4/11 [protobuf]
#    -------------- -------------------------  4/11 [protobuf]
#    -------------- -------------------------  4/11 [protobuf]
#    -------------- -------------------------  4/11 [protobuf]
#    -------------- -------------------------  4/11 [protobuf]
#    -------------- -------------------------  4/11 [protobuf]
#    -------------- -------------------------  4/11 [protobuf]
#    -------------- -------------------------  4/11 [protobuf]
#    -------------- -------------------------  4/11 [protobuf]
#    -------------- -------------------------  4/11 [protobuf]
#    -------------- -------------------------  4/11 [protobuf]
#    -------------- -------------------------  4/11 [protobuf]
#    -------------- -------------------------  4/11 [protobuf]
#    -------------- -------------------------  4/11 [protobuf]
#    ------------------ ---------------------  5/11 [mdurl]
#    --------------------- ------------------  6/11 [markdown-it-py]
#    --------------------- ------------------  6/11 [markdown-it-py]
#    --------------------- ------------------  6/11 [markdown-it-py]
#    --------------------- ------------------  6/11 [markdown-it-py]
#    --------------------- ------------------  6/11 [markdown-it-py]
#    --------------------- ------------------  6/11 [markdown-it-py]
#    --------------------- ------------------  6/11 [markdown-it-py]
#    --------------------- ------------------  6/11 [markdown-it-py]
#    --------------------- ------------------  6/11 [markdown-it-py]
#    --------------------- ------------------  6/11 [markdown-it-py]
#    --------------------- ------------------  6/11 [markdown-it-py]
#    --------------------- ------------------  6/11 [markdown-it-py]
#    --------------------- ------------------  6/11 [markdown-it-py]
#    --------------------- ------------------  6/11 [markdown-it-py]
#    ------------------------- --------------  7/11 [kagglesdk]
#    ------------------------- --------------  7/11 [kagglesdk]
#    ------------------------- --------------  7/11 [kagglesdk]
#    ------------------------- --------------  7/11 [kagglesdk]
#    ------------------------- --------------  7/11 [kagglesdk]
#    ------------------------- --------------  7/11 [kagglesdk]
#    ------------------------- --------------  7/11 [kagglesdk]
#    ------------------------- --------------  7/11 [kagglesdk]
#    ------------------------- --------------  7/11 [kagglesdk]
#    ------------------------- --------------  7/11 [kagglesdk]
#    ------------------------- --------------  7/11 [kagglesdk]
#    ------------------------- --------------  7/11 [kagglesdk]
#    ------------------------- --------------  7/11 [kagglesdk]
#    ------------------------- --------------  7/11 [kagglesdk]
#    ------------------------- --------------  7/11 [kagglesdk]
#    ------------------------- --------------  7/11 [kagglesdk]
#    ------------------------- --------------  7/11 [kagglesdk]
#    ------------------------- --------------  7/11 [kagglesdk]
#    ------------------------- --------------  7/11 [kagglesdk]
#    ------------------------- --------------  7/11 [kagglesdk]
#    ------------------------- --------------  7/11 [kagglesdk]
#    ------------------------- --------------  7/11 [kagglesdk]
#    ------------------------- --------------  7/11 [kagglesdk]
#    ------------------------- --------------  7/11 [kagglesdk]
#    ------------------------- --------------  7/11 [kagglesdk]
#    ------------------------- --------------  7/11 [kagglesdk]
#    ------------------------- --------------  7/11 [kagglesdk]
#    ------------------------- --------------  7/11 [kagglesdk]
#    ----------------------------- ----------  8/11 [mdit-py-plugins]
#    ----------------------------- ----------  8/11 [mdit-py-plugins]
#    ----------------------------- ----------  8/11 [mdit-py-plugins]
#    ----------------------------- ----------  8/11 [mdit-py-plugins]
#    ----------------------------- ----------  8/11 [mdit-py-plugins]
#    ----------------------------- ----------  8/11 [mdit-py-plugins]
#    ----------------------------- ----------  8/11 [mdit-py-plugins]
#    -------------------------------- -------  9/11 [jupytext]
#    -------------------------------- -------  9/11 [jupytext]
#    -------------------------------- -------  9/11 [jupytext]
#    -------------------------------- -------  9/11 [jupytext]
#    -------------------------------- -------  9/11 [jupytext]
#    -------------------------------- -------  9/11 [jupytext]
#    -------------------------------- -------  9/11 [jupytext]
#    -------------------------------- -------  9/11 [jupytext]
#    -------------------------------- -------  9/11 [jupytext]
#    -------------------------------- -------  9/11 [jupytext]
#    -------------------------------- -------  9/11 [jupytext]
#    ------------------------------------ --- 10/11 [kaggle]
#    ------------------------------------ --- 10/11 [kaggle]
#    ------------------------------------ --- 10/11 [kaggle]
#    ------------------------------------ --- 10/11 [kaggle]
#    ------------------------------------ --- 10/11 [kaggle]
#    ---------------------------------------- 11/11 [kaggle]
#
# Successfully installed jupytext-1.19.3 kaggle-2.2.1 kagglesdk-0.1.28 markdown-it-py-4.2.0 mdit-py-plugins-0.6.1 mdurl-0.1.2 protobuf-7.35.0 python-dotenv-1.2.2 python-slugify-8.0.4 text-unidecode-1.3 tqdm-4.68.2
# [notice] A new release of pip is available: 26.1.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import os
os.environ['KAGGLE_USERNAME'] = data['username']
os.environ['KAGGLE_KEY'] = data['key']

# %%
from kaggle.api.kaggle_api_extended import KaggleApi
api = KaggleApi()
api.authenticate()

# %%
api.dataset_download_files('dineshpiyasamara/sentiment-analysis-dataset', path='../artifacts/')
# Out:
# Dataset URL: https://www.kaggle.com/datasets/dineshpiyasamara/sentiment-analysis-dataset

# %%
import zipfile
with zipfile.ZipFile('../artifacts/sentiment-analysis-dataset.zip', 'r') as zip_ref:
    zip_ref.extractall('../artifacts/')
